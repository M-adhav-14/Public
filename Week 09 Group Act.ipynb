# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %%
employee=pd.read_csv(r"C:\Users\Madhav\Downloads\employee.csv",index_col='name')

# %%
employee
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# S Kumar         NaN  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma   NaN  62000.0    NaN       Sales    G3                649
# James Authur   54.0      NaN      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# Select rows for specific names Jack Morgan and Josh wills.

# %%
employee.loc[['Jack Morgan','Josh Wills']]
# Out:
#               age   income gender department grade  performance_score
# name
# Jack Morgan  32.0  35000.0      M    Finance    G2                674
# Josh Wills   54.0  52000.0      F    Finance    G3                901

# %% [markdown]
# Select data for multiple values "Sales" and “Finance”.

# %%
employee.loc[employee['department'].isin(['Sales','Finance'])]
# Out:
#                 age   income gender department grade  performance_score
# name
# S Kumar         NaN  16000.0      F    Finance    G0                520
# Jack Morgan    32.0  35000.0      M    Finance    G2                674
# Ying Chin      45.0  65000.0      F      Sales    G3                556
# Satyam Sharma   NaN  62000.0    NaN      Sales    G3                649
# Josh Wills     54.0  52000.0      F    Finance    G3                901
# Leo Duck       23.0  98000.0      M      Sales    G4                709

# %% [markdown]
# Display employee who has more than 700 performance score.

# %%
employee.loc[employee['performance_score']>700]&
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# Display employee who has more than 500 and less than 700 performance score

# %%
employee[(employee['performance_score'] > 500) & (employee['performance_score'] < 700)]
# Out:
#                 age   income gender department grade  performance_score
# name
# S Kumar         NaN  16000.0      F    Finance    G0                520
# Jack Morgan    32.0  35000.0      M    Finance    G2                674
# Ying Chin      45.0  65000.0      F      Sales    G3                556
# Satyam Sharma   NaN  62000.0    NaN      Sales    G3                649

# %% [markdown]
# Check and handle missing values in the dataset

# %%
employee.isnull().sum()
# Out:
# age                  2
# income               2
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %%
employee
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# S Kumar         NaN  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma   NaN  62000.0    NaN       Sales    G3                649
# James Authur   54.0      NaN      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %%
# Handling Nan values in Age Column

# %%
employee=employee.fillna({'age':25},limit=1)

# %%
employee=employee.fillna({'age':employee['age'].mean()},limit=1)

# %%
employee.round(0)
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# S Kumar        25.0  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma  38.0  62000.0    NaN       Sales    G3                649
# James Authur   54.0      NaN      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %%
# Handling NaN values in Income Column

# %%
employee=employee.fillna({'income':employee['income'].mean()},limit=2)

# %%
employee.round(0)
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0  52857.0    NaN  Operations    G3                723
# S Kumar        25.0  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma  38.0  62000.0    NaN       Sales    G3                649
# James Authur   54.0  52857.0      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %%
# Handling NaN values in Gender Column.

# %%
employee=employee.fillna({'gender':'M'},limit=2)

# %%
employee.round(0)
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0  52857.0      M  Operations    G3                723
# S Kumar        25.0  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma  38.0  62000.0      M       Sales    G3                649
# James Authur   54.0  52857.0      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# Check the outliers and handle outliers in performance score using Percentiles

# %%
plt.figure(figsize=(10,6))
sns.boxplot(y='performance_score',data=employee,palette='Accent')
# Out:
# <AxesSubplot:ylabel='performance_score'>

# %%
Q1=employee.performance_score.quantile(0.25)
Q3=employee.performance_score.quantile(0.75)
print(Q1,Q3)
# Out:
# 556.0 711.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 155.0

# %%
lower=Q1-1.5*(IQR)
upper=Q3+1.5*(IQR)
print(lower,upper)
# Out:
# 323.5 943.5

# %%
outliers=employee[(employee.performance_score<lower) | (employee.performance_score>upper)]
outliers
# Out:
#                age        income gender  department grade  performance_score
# name
# James Authur  54.0  52857.142857      F  Operations    G3                 53

# %%
employee["performance_score"] = np.where(new_employee["performance_score"]> upper, upper,
                        np.where(employee["performance_score"]< lower, lower,
                          employee["performance_score"]))

# %%
employee
# Out:
#                 age        income gender  department grade  performance_score
# name
# Allen Smith    45.0  52857.142857      M  Operations    G3              723.0
# S Kumar        25.0  16000.000000      F     Finance    G0              520.0
# Jack Morgan    32.0  35000.000000      M     Finance    G2              674.0
# Ying Chin      45.0  65000.000000      F       Sales    G3              556.0
# Dheeraj Patel  30.0  42000.000000      F  Operations    G2              711.0
# Satyam Sharma  38.5  62000.000000      M       Sales    G3              649.0
# James Authur   54.0  52857.142857      F  Operations    G3              323.5
# Josh Wills     54.0  52000.000000      F     Finance    G3              901.0
# Leo Duck       23.0  98000.000000      M       Sales    G4              709.0

# %%
plt.figure(figsize=(10,6))
sns.boxplot(y='performance_score',data=employee,palette='Accent')
# Out:
# <AxesSubplot:ylabel='performance_score'>

# %% [markdown]
# Check the gender column and do Dummy encoding.

# %%
emp=employee

# %%
emp
# Out:
#                 age        income gender  department grade  performance_score
# name
# Allen Smith    45.0  52857.142857      M  Operations    G3              723.0
# S Kumar        25.0  16000.000000      F     Finance    G0              520.0
# Jack Morgan    32.0  35000.000000      M     Finance    G2              674.0
# Ying Chin      45.0  65000.000000      F       Sales    G3              556.0
# Dheeraj Patel  30.0  42000.000000      F  Operations    G2              711.0
# Satyam Sharma  38.5  62000.000000      M       Sales    G3              649.0
# James Authur   54.0  52857.142857      F  Operations    G3              323.5
# Josh Wills     54.0  52000.000000      F     Finance    G3              901.0
# Leo Duck       23.0  98000.000000      M       Sales    G4              709.0

# %%
emp=pd.get_dummies(emp,columns=['gender'],drop_first=True)

# %%
emp
# Out:
#                 age        income  department grade  performance_score  \
# name
# Allen Smith    45.0  52857.142857  Operations    G3              723.0
# S Kumar        25.0  16000.000000     Finance    G0              520.0
# Jack Morgan    32.0  35000.000000     Finance    G2              674.0
# Ying Chin      45.0  65000.000000       Sales    G3              556.0
# Dheeraj Patel  30.0  42000.000000  Operations    G2              711.0
# Satyam Sharma  38.5  62000.000000       Sales    G3              649.0
# James Authur   54.0  52857.142857  Operations    G3              323.5
# Josh Wills     54.0  52000.000000     Finance    G3              901.0
# Leo Duck       23.0  98000.000000       Sales    G4              709.0
#
#                gender_M
# name
# Allen Smith           1
# S Kumar               0
# Jack Morgan           1
# Ying Chin             0
# Dheeraj Patel         0
# Satyam Sharma         1
# James Authur          0
# Josh Wills            0
# ...

# %% [markdown]
# Do the standard scaling on the feature performance score.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled_features = emp.copy()
 
col_names = ['performance_score']
features = scaled_features[col_names]
scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)
 
scaled_features[col_names] = features
print(scaled_features)
# Out:
#                 age        income  department grade  performance_score  \
# name
# Allen Smith    45.0  52857.142857  Operations    G3           0.541644
# S Kumar        25.0  16000.000000     Finance    G0          -0.794729
# Jack Morgan    32.0  35000.000000     Finance    G2           0.219072
# Ying Chin      45.0  65000.000000       Sales    G3          -0.557736
# Dheeraj Patel  30.0  42000.000000  Operations    G2           0.462647
# Satyam Sharma  38.5  62000.000000       Sales    G3           0.054494
# James Authur   54.0  52857.142857  Operations    G3          -2.088312
# Josh Wills     54.0  52000.000000     Finance    G3           1.713440
# Leo Duck       23.0  98000.000000       Sales    G4           0.449481
#
#                gender_M
# name
# Allen Smith           1
# S Kumar               0
# Jack Morgan           1
# Ying Chin             0
# Dheeraj Patel         0
# Satyam Sharma         1
# James Authur          0
# Josh Wills            0
# ...

# %%
emp=scaled_features
emp
# Out:
#                 age        income  department grade  performance_score  \
# name
# Allen Smith    45.0  52857.142857  Operations    G3           0.541644
# S Kumar        25.0  16000.000000     Finance    G0          -0.794729
# Jack Morgan    32.0  35000.000000     Finance    G2           0.219072
# Ying Chin      45.0  65000.000000       Sales    G3          -0.557736
# Dheeraj Patel  30.0  42000.000000  Operations    G2           0.462647
# Satyam Sharma  38.5  62000.000000       Sales    G3           0.054494
# James Authur   54.0  52857.142857  Operations    G3          -2.088312
# Josh Wills     54.0  52000.000000     Finance    G3           1.713440
# Leo Duck       23.0  98000.000000       Sales    G4           0.449481
#
#                gender_M
# name
# Allen Smith           1
# S Kumar               0
# Jack Morgan           1
# Ying Chin             0
# Dheeraj Patel         0
# Satyam Sharma         1
# James Authur          0
# Josh Wills            0
# ...
