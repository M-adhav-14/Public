# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic=pd.read_csv(r"C:\Users\Madhav\Downloads\titanic_dataset.csv",index_col='PassengerId')

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# Check the basic details of the dataset

# %%
titanic.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
titanic.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %% [markdown]
# Fill in all the missing values present in all the columns in the dataset

# %%
# Handling Nan values in Age Column

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic=titanic.fillna({'Age':titanic['Age'].mean()},limit=177)

# %%
titanic.round(0)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# Handling NaN values in Cabin column; as most of the values are empty in the column 'Cabin', the column is dropped.

# %%
titanic. drop('Cabin', axis=1, inplace=True)

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
# Handling NaN values in Embarked column

# %%
titanic.select_dtypes(include='object').fillna("C", inplace=True)

# %%
titanic.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# Check and handle outliers in at least 3 columns in the dataset

# %%
# Handling outliers in Ticket Column.

# %%
plt.figure(figsize=(10,6))
sns.boxplot(y='Fare',data=titanic,palette='Accent')
# Out:
# <AxesSubplot:ylabel='Fare'>

# %%
Q1=titanic.Fare.quantile(0.25)
Q3=titanic.Fare.quantile(0.75)
print(Q1,Q3)
# Out:
# 7.9104 31.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 23.0896

# %%
lower=Q1-1.5*(IQR)
upper=Q3+1.5*(IQR)
print(lower,upper)
# Out:
# -26.724 65.6344

# %%
outliers=titanic[(titanic.Fare<lower) | (titanic.Fare>upper)]
outliers
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 28                  0       1
# 32                  1       1
# 35                  0       1
# 53                  1       1
# ...               ...     ...
# 847                 0       3
# 850                 1       1
# 857                 1       1
# 864                 0       3
# 880                 1       1
#
#                                                           Name     Sex  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 28                              Fortune, Mr. Charles Alexander    male
# 32              Spencer, Mrs. William Augustus (Marie Eugenie)  female
# 35                                     Meyer, Mr. Edgar Joseph    male
# 53                    Harper, Mrs. Henry Sleeper (Myna Haxtun)  female
# ...                                                        ...     ...
# ...

# %%
titanic["Fare"] = np.where(titanic["Fare"]> upper, upper,
                        np.where(titanic["Fare"]< lower, lower,
                          titanic["Fare"]))

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(y='Fare',data=titanic,palette='Accent')
# Out:
# <AxesSubplot:ylabel='Fare'>

# %%
# Handling outliers in SibSp Column.

# %%
plt.figure(figsize=(10,6))
sns.boxplot(y='SibSp',data=titanic,palette='Accent')
# Out:
# <AxesSubplot:ylabel='SibSp'>

# %%
Q1=titanic.SibSp.quantile(0.25)
Q3=titanic.SibSp.quantile(0.75)
print(Q1,Q3)
# Out:
# 0.0 1.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 1.0

# %%
lower=Q1-1.5*(IQR)
upper=Q3+1.5*(IQR)
print(lower,upper)
# Out:
# -1.5 2.5

# %%
titanic["SibSp"] = np.where(titanic["SibSp"]> upper, upper,
                        np.where(titanic["SibSp"]< lower, lower,
                          titanic["SibSp"]))

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(y='SibSp',data=titanic,palette='Accent')
# Out:
# <AxesSubplot:ylabel='SibSp'>
